# %%
import matplotlib.pyplot as plt
import networkx as nx

from er import get_er
from shk import get_shk

# %%
# graph = get_er(8, 2)
graph = get_shk(50, p=0.3, q=0.1, r=1.0, s=0.2)
fig, ax = plt.subplots(figsize=(5,5))
nx.draw(graph, ax=ax, node_color="k", node_size=100, pos=nx.kamada_kawai_layout(graph))

fig.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))
nx.draw(graph, ax=ax, node_color="k", node_size=100, linewidths=2.0, pos=nx.kamada_kawai_layout(graph))

fig.show()
fig.savefig("/pds/pds11/hoyun/shk2.png", transparent=True)
